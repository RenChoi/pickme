# %% [markdown]
# <a href="https://colab.research.google.com/github/RenChoi/pickme/blob/main/%D0%BF%D0%B8%D1%82%D0%BE%D0%BD%D1%87%D0%B8%D0%BA_1504.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Мазанов Артем 09-313

# %% [markdown]
# инициализация нового локального репозитория №1
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# добавление файла в индекс для коммита
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# создание нового коммита
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# просмотр истории коммитов
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# просмотр изменений в файлах перед коммитом
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# откат изменений в файле до предыдущего коммита
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# создание новой ветки
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# переключение между ветками
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# слияние веток
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# удаление ветки
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# изменение сообщения последнего коммита
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# удаление файла из репозитория и истории коммитов
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# игнорирование файлов и папок с помощью .gitignore
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# просмотр различий между ветками
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# отмена изменений в файле после добавления в индекс
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# просмотр информации о состоянии репозитория
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# переименование файлов
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Отображение информации о коммите

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Возврат к определенному коммиту

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# создание и применение патчей

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Изменение порядка коммитов
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Изменение авторства коммитов

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Изменение истории коммитов с помощью rebase
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Использование stash для временного сохранения изменений
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Применение изменений из одной ветки в другую с помощью cherry-pick
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Просмотр информации о ветках и удаленных репозиториях
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Изменение URL удаленного репозитория
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Удаление коммитов из истории
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Использование алиасов для команд Git
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Использование подмодулей для работы с вложенными репозиториями
# ![image.png](data:image/png;base64,...)
