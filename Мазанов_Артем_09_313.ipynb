# %% [markdown]
# <a href="https://colab.research.google.com/github/RenChoi/-_-/blob/main/%D0%9C%D0%B0%D0%B7%D0%B0%D0%BD%D0%BE%D0%B2_%D0%90%D1%80%D1%82%D0%B5%D0%BC_09_313.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Лаб 1

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Task 1
z = int(input("Enter z: "))
t = (4*z - 4)**2/(4-8*z+8*(z**2))
print(f"t={t}")
# Out:
# Enter z: 1
# t=0.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Task 2
from math import log
x = int(input("Enter x: "))
w = log(x**2)/(1+log(x)**2)
print(f"w={w}")
# Out:
# Enter x: 2
# w=0.9363987563853118

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Task 3
from math import fabs
x = int(input("Enter x: "))
a = -2*x + 3*x**2 -4*x**3
b = 1 + fabs(a)
print(f"A : {a}\n B: {b}")
# Out:
# Enter x: 1
# A : -3
#  B: 4.0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Task 4
n = int(input("Enter n: "))
a = n//3600
print(f'Количество полных часов:{a}')
# Out:
# Enter n: 3599
# Количество полных часов:0

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
#Task 5
a = int(input("Enter a: "))
b = int(input("Enter b: "))
c = ((a%2!=0)&(b%2!=0))
print(f'A и В оба нечетные: {c}')
# Out:
# Enter a: 2
# Enter b: 4
# A и В оба нечетные: False

# %% [markdown]
# ## Лаб 2

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Task 1
